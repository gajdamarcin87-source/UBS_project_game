# %%
import pandas as pd
from pathlib import Path

csv_file_easy = Path("quiz_easy_100.csv")
csv_file_medium = Path("quiz_medium_100.csv")
csv_file_hard = Path("quiz_hard_100.csv")

easy_df = pd.read_csv(csv_file_easy)
medium_df = pd.read_csv(csv_file_medium)
hard_df = pd.read_csv(csv_file_hard)

easy_df
# Out:
#     Question_ID Difficulty                 Category  \
# 0             1       Easy           Arts and Music
# 1             2       Easy           Arts and Music
# 2             3       Easy         Sports and Games
# 3             4       Easy       Nature and Biology
# 4             5       Easy  Literature and Language
# ..          ...        ...                      ...
# 95           96       Easy                  History
# 96           97       Easy       Nature and Biology
# 97           98       Easy                  History
# 98           99       Easy                Geography
# 99          100       Easy              Mathematics
#
#                                              Question               A  \
# 0   Which art form creates three-dimensional figur...     Photography
# 1       How many strings does a standard violin have?            Four
# 2         In which sport would you score a touchdown?      Basketball
# 3     Which animal is the tallest living land animal?        Elephant
# 4   Which fictional detective lives at 221B Baker ...  Hercule Poirot
# ..                                                ...             ...
# 95           Which country did the samurai come from?           Japan
# 96                        What is a baby frog called?             Cub
# 97  What did medieval knights typically wear for p...           Kilts
# 98        Which country has a maple leaf on its flag?          Mexico
# 99                              Which number is even?              27
#
#                     B                    C           D Correct_Answer
# 0         Calligraphy  Watercolor painting   Sculpture              D
# 1               Three                 Five         Six              A
# 2   American football           Ice hockey    Baseball              B
# 3             Ostrich              Giraffe       Camel              C
# 4     Sherlock Holmes          Miss Marple  Nancy Drew              B
# ..                ...                  ...         ...            ...
# 95           Mongolia                India       China              A
# 96            Tadpole                 Foal        Calf              B
# 97              Togas                Armor   Lab coats              C
# 98             Canada               Brazil   Argentina              B
# 99                 18                   21          15              B
#
# [100 rows x 9 columns]

# %%
quiz_dificulty = int(input("Select quiz difficulty (1: Easy, 2: Medium, 3: Hard): "))
